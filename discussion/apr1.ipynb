# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from astropy.io import fits

# %%
fit = fits.open('fits_file_disc.fits')

# %%
test_fits.info()
# Out:
# Filename: fits_file_disc.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1                1 BinTableHDU     12   31023R x 2C   [E, E]

# %%
with fits.open('fits_file_disc.fits') as hdul:
    data = fit[1].data
    hdr = fit[1].header

# %%
hdr
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                    8 / length of dimension 1
# NAXIS2  =                31023 / length of dimension 2
# PCOUNT  =                    0 / number of group parameters
# GCOUNT  =                    1 / number of groups
# TFIELDS =                    2 / number of table fields
# TTYPE1  = 'Wavelength (Angstroms)'
# TFORM1  = 'E       '
# TTYPE2  = 'Flux    '
# TFORM2  = 'E       '

# %%
data.field('Flux')
# Out:
# array([4.3531495e-10, 4.3527074e-10, 4.3521931e-10, ..., 5.2378674e-10,
#        5.2362126e-10, 5.2347715e-10], dtype=float32)

# %%
data.field('Wavelength (Angstroms)')
# Out:
# array([  500.    ,   500.0834,   500.1668, ..., 59995.562 , 60005.562 ,
#        60015.574 ], dtype=float32)

# %%
y = data.field('Flux')
x = data.field('Wavelength (Angstroms)')

plt.scatter(x, y, s=0.1)
